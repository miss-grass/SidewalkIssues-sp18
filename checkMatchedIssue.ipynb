# %%
import numpy as np
import pandas as pd

# %%
data = np.load('/Users/Miss-grass/Documents/CSE495/Sp18/finalweek/newIssues_0-207.npy')
issues = pd.read_csv('/Users/Miss-grass/Documents/CSE495/Win18/SidewalkObservations.csv', skipinitialspace=True, dtype=object)

# %%
i = 0
severe = 0
for row in data:
    if len(row) > 0:
        issue = issues.iloc[[i]]
        if issue.OBSERV_TYPE.item() == 'HEIGHTDIFF':
            print('issue ' + str(i))
            print('height diff: ' + issue.HEIGHT_DIFFERENCE.item())
            if float(issue.HEIGHT_DIFFERENCE.item()) >= 3.5:
                severe += 1
    i+=1
print("")
print("There are a total of " + str(severe) + " severe routes classified by HEIGHTDIFF >= 3.5 here.")
# Out:
# issue 2034
# height diff: 1.71
# issue 2038
# height diff: 1.03
# issue 2041
# height diff: 1.22
# issue 10445
# height diff: 0.67
# issue 10447
# height diff: 0.9399999999999999
# issue 10476
# height diff: 1.42
# issue 10482
# height diff: 0.59
# issue 10483
# height diff: 0.58
# issue 10489
# height diff: 0.82
# issue 10491
# height diff: 0.63
# issue 10496
# height diff: 0.8
# issue 10507
# height diff: 0.72
# issue 10508
# height diff: 0.4
# issue 10535
# height diff: 1.37
# issue 10589
# height diff: 0.47
# issue 10593
# height diff: 1.17
# issue 10602
# height diff: 0.67
# issue 10608
# height diff: 0.4
# issue 10614
# height diff: 0.64
# issue 10615
# height diff: 1.11
# issue 11056
# height diff: 1.24
# issue 11311
# height diff: 1.02
# issue 13230
# height diff: 0.95
# issue 22049
# height diff: 0.79
# issue 22056
# height diff: 0.8
# issue 25246
# height diff: 0.47
# issue 25259
# height diff: 1.01
# issue 25513
# height diff: 0.93
# issue 25529
# height diff: 1.03
# issue 27114
# height diff: 0.6899999999999999
# issue 27126
# height diff: 0.73
# issue 27861
# height diff: 1.07
# issue 28192
# height diff: 1.01
# issue 32110
# height diff: 0.49
# issue 32126
# height diff: 0.64
# issue 32128
# height diff: 0.77
# issue 33107
# height diff: 0.52
# issue 33263
# height diff: 0.61
# issue 33267
# height diff: 2.7
# issue 33755
# height diff: 0.6899999999999999
# issue 33758
# height diff: 0.67
# issue 37562
# height diff: 0.8100000000000001
# issue 37572
# height diff: 1.17
# issue 39351
# height diff: 1
# issue 39355
# height diff: 0.47
# issue 39619
# height diff: 0.47
# issue 46767
# height diff: 0.81
# issue 46769
# height diff: 0.54
# issue 46772
# height diff: 0.7
# issue 46774
# height diff: 0.6
# issue 95612
# height diff: 0.66
# issue 95614
# height diff: 0.49
# issue 95620
# height diff: 0.83
# issue 95626
# height diff: 0.52
# issue 102879
# height diff: 0.92
# issue 103854
# height diff: 0.61
# issue 103858
# height diff: 0.96
#
# There are a total of 0 severe routes classified by HEIGHTDIFF >= 3.5 here.

# %%
data2 = np.load('/Users/Miss-grass/Documents/CSE495/Sp18/finalweek/newIssues2_0-207.npy')

# %%
i = 0
severe = 0
for row in data2:
    if len(row) > 0:
        issue = issues.iloc[[i]]
        if issue.OBSERV_TYPE.item() == 'HEIGHTDIFF':
            print('issue ' + str(i))
            print('height diff: ' + issue.HEIGHT_DIFFERENCE.item())
            if float(issue.HEIGHT_DIFFERENCE.item()) >= 3.5:
                severe += 1
    i+=1
print("")
print("There are a total of " + str(severe) + " severe routes classified by HEIGHTDIFF >= 3.5 here.")
# Out:
# issue 2034
# height diff: 1.71
# issue 2038
# height diff: 1.03
# issue 2041
# height diff: 1.22
# issue 10445
# height diff: 0.67
# issue 10447
# height diff: 0.9399999999999999
# issue 10450
# height diff: 1.42
# issue 10452
# height diff: 0.95
# issue 10476
# height diff: 1.42
# issue 10482
# height diff: 0.59
# issue 10483
# height diff: 0.58
# issue 10489
# height diff: 0.82
# issue 10491
# height diff: 0.63
# issue 10496
# height diff: 0.8
# issue 10507
# height diff: 0.72
# issue 10508
# height diff: 0.4
# issue 10535
# height diff: 1.37
# issue 10589
# height diff: 0.47
# issue 10593
# height diff: 1.17
# issue 10602
# height diff: 0.67
# issue 10608
# height diff: 0.4
# issue 10614
# height diff: 0.64
# issue 10615
# height diff: 1.11
# issue 10707
# height diff: 0.97
# issue 11056
# height diff: 1.24
# issue 11311
# height diff: 1.02
# issue 11472
# height diff: 0.99
# issue 13230
# height diff: 0.95
# issue 22049
# height diff: 0.79
# issue 22056
# height diff: 0.8
# issue 22310
# height diff: 0.75
# issue 25246
# height diff: 0.47
# issue 25259
# height diff: 1.01
# issue 25513
# height diff: 0.93
# issue 25529
# height diff: 1.03
# issue 27004
# height diff: 1.05
# issue 27011
# height diff: 0.72
# issue 27114
# height diff: 0.6899999999999999
# issue 27126
# height diff: 0.73
# issue 27861
# height diff: 1.07
# issue 27897
# height diff: 0.6
# issue 28192
# height diff: 1.01
# issue 28193
# height diff: 0.73
# issue 32110
# height diff: 0.49
# issue 32126
# height diff: 0.64
# issue 32128
# height diff: 0.77
# issue 33107
# height diff: 0.52
# issue 33263
# height diff: 0.61
# issue 33267
# height diff: 2.7
# issue 33755
# height diff: 0.6899999999999999
# issue 33758
# height diff: 0.67
# issue 37562
# height diff: 0.8100000000000001
# issue 37572
# height diff: 1.17
# issue 37590
# height diff: 0.53
# issue 39351
# height diff: 1
# issue 39355
# height diff: 0.47
# issue 39619
# height diff: 0.47
# issue 46766
# height diff: 0.41
# issue 46767
# height diff: 0.81
# issue 46769
# height diff: 0.54
# issue 46772
# height diff: 0.7
# issue 46774
# height diff: 0.6
# issue 95612
# height diff: 0.66
# issue 95614
# height diff: 0.49
# issue 95620
# height diff: 0.83
# issue 95626
# height diff: 0.52
# issue 102879
# height diff: 0.92
# issue 103854
# height diff: 0.61
# issue 103858
# height diff: 0.96
#
# There are a total of 0 severe routes classified by HEIGHTDIFF >= 3.5 here.
